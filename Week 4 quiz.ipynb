# %% [markdown]
# ## Week 4 Quiz

# %%
import pandas as pd
import numpy as np
import seaborn as sns   # Why sns?  It's a reference to The West Wing
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
sns.set(color_codes=True) # adds a nice background to the graphs
# %matplotlib inline  
# tells python to actually display the graphs

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Slump+test.csv')

# %%
data.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse   Fine  SLUMP  FLOW  Strength
# 0   273.0   82.0    105.0  210.0   9.0   904.0  680.0   23.0  62.0     34.99
# 1   163.0  149.0    191.0  180.0  12.0   843.0  746.0    0.0  20.0     41.14
# 2   162.0  148.0    191.0  179.0  16.0   840.0  743.0    1.0  20.0     41.81
# 3   162.0  148.0    190.0  179.0  19.0   838.0  741.0    3.0  21.5     42.08
# 4   154.0  112.0    144.0  220.0  10.0   923.0  658.0   20.0  64.0     26.82

# %%
data.shape
# Out:
# (103, 10)

# %%
data.describe()
# Out:
#            Cement        Slag     Fly ash       Water          SP  \
# count  103.000000  103.000000  103.000000  103.000000  103.000000
# mean   229.894175   77.973786  149.014563  197.167961    8.539806
# std     78.877230   60.461363   85.418080   20.208158    2.807530
# min    137.000000    0.000000    0.000000  160.000000    4.400000
# 25%    152.000000    0.050000  115.500000  180.000000    6.000000
# 50%    248.000000  100.000000  164.000000  196.000000    8.000000
# 75%    303.900000  125.000000  235.950000  209.500000   10.000000
# max    374.000000  193.000000  260.000000  240.000000   19.000000
#
#             Coarse        Fine       SLUMP       FLOW    Strength
# count   103.000000  103.000000  103.000000  103.00000  103.000000
# mean    883.978641  739.604854   18.048544   49.61068   36.039417
# std      88.391393   63.342117    8.750844   17.56861    7.838232
# min     708.000000  640.600000    0.000000   20.00000   17.190000
# ...

# %%
data.columns
# Out:
# Index(['Cement', 'Slag', 'Fly ash', 'Water', 'SP', 'Coarse', 'Fine', 'SLUMP',
#        'FLOW', 'Strength'],
#       dtype='object')

# %%
data.dtypes.value_counts()
# Out:
# float64    10
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Cement    103 non-null    float64
#  1   Slag      103 non-null    float64
#  2   Fly ash   103 non-null    float64
#  3   Water     103 non-null    float64
#  4   SP        103 non-null    float64
#  5   Coarse    103 non-null    float64
#  6   Fine      103 non-null    float64
#  7   SLUMP     103 non-null    float64
#  8   FLOW      103 non-null    float64
#  9   Strength  103 non-null    float64
# dtypes: float64(10)
# memory usage: 8.2 KB

# %%
data.isnull().sum()
# Out:
# Cement      0
# Slag        0
# Fly ash     0
# Water       0
# SP          0
# Coarse      0
# Fine        0
# SLUMP       0
# FLOW        0
# Strength    0
# dtype: int64

# %%
data.mode()
# in the test, I stated 19, but in reality, I forgot to count that data starts from 0
# so that's 20 modes for the column 'Strength'
# Out:
#     Cement  Slag  Fly ash  Water   SP  Coarse   Fine  SLUMP  FLOW  Strength
# 0    159.0   0.0      0.0  168.0  6.0   904.0  757.0    0.0  20.0     26.42
# 1      NaN   NaN      NaN  174.0  NaN     NaN    NaN    NaN   NaN     28.29
# 2      NaN   NaN      NaN  179.0  NaN     NaN    NaN    NaN   NaN     29.77
# 3      NaN   NaN      NaN  180.0  NaN     NaN    NaN    NaN   NaN     30.43
# 4      NaN   NaN      NaN  183.0  NaN     NaN    NaN    NaN   NaN     30.97
# 5      NaN   NaN      NaN  193.0  NaN     NaN    NaN    NaN   NaN     32.71
# 6      NaN   NaN      NaN  205.0  NaN     NaN    NaN    NaN   NaN     33.51
# 7      NaN   NaN      NaN  207.0  NaN     NaN    NaN    NaN   NaN     33.78
# 8      NaN   NaN      NaN  208.0  NaN     NaN    NaN    NaN   NaN     34.99
# 9      NaN   NaN      NaN  210.0  NaN     NaN    NaN    NaN   NaN     35.52
# 10     NaN   NaN      NaN    NaN  NaN     NaN    NaN    NaN   NaN     36.19
# ...

# %%
# Another way to look at the number of modes for column 'Strength'
len(data['Strength'].mode())
# Out:
# 20

# %%
# the way to look at mean, median and mode for column 'Fly ash'

mean_fly_ash=data['Fly ash'].mean()
median_fly_ash=data['Fly ash'].median()
mode_fly_ash=data['Fly ash'].mode()
print("Mean=",mean_fly_ash)
print("Median=",median_fly_ash)
print("Mode=",mode_fly_ash)

# you could also look at data.describe(), but might take slightly longer to find all the data you need
# Out:
# Mean= 149.0145631067961
# Median= 164.0
# Mode= 0    0.0
# dtype: float64

# %%
data.cov()
# Out:
#                Cement         Slag      Fly ash        Water         SP  \
# Cement    6221.617417 -1161.508095 -3278.051679   352.411380 -23.559374
# Slag     -1161.508095  3655.576463 -1666.164124   -32.713593  52.028211
# Fly ash  -3278.051679 -1666.164124  7296.248315  -416.553646 -34.415193
# Water      352.411380   -32.713593  -416.553646   408.369650  -8.819791
# SP         -23.559374    52.028211   -34.415193    -8.819791   7.882223
# Coarse   -2160.342969 -1196.005958  1303.319236 -1075.668338 -25.848357
# Fine       284.580813  -702.843499 -1530.400660   146.679569  10.366079
# SLUMP      100.714991  -150.280333   -88.667135    82.507208  -5.230628
# FLOW       258.390259  -347.591678   -83.172706   224.387600  -8.696606
# Strength   275.572938  -157.142937   297.532714   -40.269862  -0.833388
#
#                Coarse         Fine       SLUMP        FLOW    Strength
# Cement   -2160.342969   284.580813  100.714991  258.390259  275.572938
# ...

# %%
# to find covariance between two data points
data[['Cement','Slag']].cov()
# Out:
#              Cement         Slag
# Cement  6221.617417 -1161.508095
# Slag   -1161.508095  3655.576463

# %%
data.corr()
# Out:
#             Cement      Slag   Fly ash     Water        SP    Coarse  \
# Cement    1.000000 -0.243553 -0.486535  0.221091 -0.106387 -0.309857
# Slag     -0.243553  1.000000 -0.322619 -0.026775  0.306504 -0.223792
# Fly ash  -0.486535 -0.322619  1.000000 -0.241321 -0.143508  0.172620
# Water     0.221091 -0.026775 -0.241321  1.000000 -0.155456 -0.602201
# SP       -0.106387  0.306504 -0.143508 -0.155456  1.000000 -0.104159
# Coarse   -0.309857 -0.223792  0.172620 -0.602201 -0.104159  1.000000
# Fine      0.056959 -0.183522 -0.282854  0.114591  0.058290 -0.488537
# SLUMP     0.145913 -0.284037 -0.118621  0.466568 -0.212902 -0.188157
# FLOW      0.186461 -0.327231 -0.055423  0.632026 -0.176314 -0.325787
# Strength  0.445725 -0.331588  0.444393 -0.254235 -0.037871 -0.160684
#
#               Fine     SLUMP      FLOW  Strength
# Cement    0.056959  0.145913  0.186461  0.445725
# Slag     -0.183522 -0.284037 -0.327231 -0.331588
# Fly ash  -0.282854 -0.118621 -0.055423  0.444393
# ...

# %%
# to find correlation between two variables
data[['Coarse','Cement']].corr()
# Out:
#           Coarse    Cement
# Coarse  1.000000 -0.309857
# Cement -0.309857  1.000000

# %%
data.skew()
# Out:
# Cement      0.145140
# Slag       -0.193079
# Fly ash    -0.680019
# Water       0.263532
# SP          1.125753
# Coarse      0.121009
# Fine        0.265958
# SLUMP      -1.112837
# FLOW       -0.520705
# Strength    0.192235
# dtype: float64

# %%
# in the above, you would simply count the number of negative skew values. Or...
# you could simply use the following formula
(data.skew(axis = 0, skipna = True)<0).sum() # skipna=True excludes NA/null values
# Out:
# 4

# %%
data.duplicated('FLOW').sum()
# Out:
# 52

# %%
data.duplicated('SLUMP').sum()
# Out:
# 64

# %%
sns.boxplot(data = data, y ='Strength');

# %%
sns.pairplot(data)

# %%
data.quantile(0.75) - data.quantile(0.25)
# Out:
# Cement      151.900
# Slag        124.950
# Fly ash     120.450
# Water        29.500
# SP            4.000
# Coarse      133.300
# Fine        103.500
# SLUMP         9.500
# FLOW         25.250
# Strength     10.305
# dtype: float64

# %%
# or, to answer what is the Inter Quartile Range (IQR) of the variable ‘Fine’?, instead of the above

from scipy import stats
IQR = stats.iqr(data['Fine']) # you can also add this after Fine'], --> interpolation = 'midpoint'

print(IQR)
# Out:
# 103.5

# %%
sns.distplot(data['Slag']);

# %%
# or, instead of the above, to find Which of the following is the frequency polygon of the variable 'Slag'?

data_slag = data['Slag']
sns.distplot(data_slag, hist=False)
# Out:
# <AxesSubplot:xlabel='Slag', ylabel='Density'>

# %%
data[data['Cement'] > 229.894175].count()
# Out:
# Cement      52
# Slag        52
# Fly ash     52
# Water       52
# SP          52
# Coarse      52
# Fine        52
# SLUMP       52
# FLOW        52
# Strength    52
# dtype: int64

# %%
# or to solve the above (find number of 'Cement' column values larger than its mean), use...

# mean of cement column
mean = data['Cement'].mean() 

#getting the number of rows that have values greater than value of mean
data[data['Cement']>mean]['Cement'].shape
# Out:
# (52,)

# %%
data[data['Cement']>data['Cement'].mean()]
# Out:
#      Cement   Slag  Fly ash  Water    SP  Coarse   Fine  SLUMP  FLOW  Strength
# 0     273.0   82.0    105.0  210.0   9.0   904.0  680.0  23.00  62.0     34.99
# 9     304.0    0.0    140.0  214.0   6.0   895.0  722.0  19.00  51.0     38.46
# 13    354.0    0.0      0.0  234.0   6.0   959.0  691.0  17.00  54.0     33.91
# 14    374.0    0.0      0.0  190.0   7.0  1013.0  730.0  14.50  42.5     32.44
# 17    295.0  106.0    136.0  206.0  11.0   750.0  766.0  25.00  68.5     41.01
# 18    310.0    0.0    143.0  168.0  10.0   914.0  804.0  20.50  48.2     49.30
# 19    296.0   97.0      0.0  219.0   9.0   932.0  685.0  15.00  48.5     29.23
# 20    305.0  100.0      0.0  196.0  10.0   959.0  705.0  20.00  49.0     29.77
# 21    310.0    0.0    143.0  218.0  10.0   787.0  804.0  13.00  46.0     36.19
# 26    308.0  111.0    142.0  217.0  10.0   783.0  686.0  25.00  70.0     42.08
# 27    295.0  106.0    136.0  208.0   6.0   871.0  650.0  26.50  70.0     39.40
# ...

# %%
sns.distplot(data['Strength'])
# Out:
# <AxesSubplot:xlabel='Strength', ylabel='Density'>

# %%
# An ogive is nothing but the cumulative distribution plot. To draw an ogive of the variable 'Strength' -
sns.distplot(data['Strength'], hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))
# Out:
# <AxesSubplot:xlabel='Strength', ylabel='Density'>

# %%
# Is the value of the 101st row of the 4th column greater than the 103rd row of the 4th column?
data.iloc[100,3] > data.iloc[102,3]
# Out:
# False
